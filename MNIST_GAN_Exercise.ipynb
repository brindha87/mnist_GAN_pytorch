# %% [markdown]
# # Generative Adversarial Network
#
# In this notebook, we'll be building a generative adversarial network (GAN) trained on the MNIST dataset. From this, we'll be able to generate new handwritten digits!
#
# GANs were [first reported on](https://arxiv.org/abs/1406.2661) in 2014 from Ian Goodfellow and others in Yoshua Bengio's lab. Since then, GANs have exploded in popularity. Here are a few examples to check out:
#
# * [Pix2Pix](https://affinelayer.com/pixsrv/)
# * [CycleGAN & Pix2Pix in PyTorch, Jun-Yan Zhu](https://github.com/junyanz/pytorch-CycleGAN-and-pix2pix)
# * [A list of generative models](https://github.com/wiseodd/generative-models)
#
# The idea behind GANs is that you have two networks, a generator $G$ and a discriminator $D$, competing against each other. The generator makes "fake" data to pass to the discriminator. The discriminator also sees real training data and predicts if the data it's received is real or fake.
# > * The generator is trained to fool the discriminator, it wants to output data that looks _as close as possible_ to real, training data.
# * The discriminator is a classifier that is trained to figure out which data is real and which is fake.
#
# What ends up happening is that the generator learns to make data that is indistinguishable from real data to the discriminator.
#
# <img src='assets/gan_pipeline.png' width=70% />
#
# The general structure of a GAN is shown in the diagram above, using MNIST images as data. The latent sample is a random vector that the generator uses to construct its fake images. This is often called a **latent vector** and that vector space is called **latent space**. As the generator trains, it figures out how to map latent vectors to recognizable images that can fool the discriminator.
#
# If you're interested in generating only new images, you can throw out the discriminator after training. In this notebook, I'll show you how to define and train these adversarial networks in PyTorch and generate new images!

# %%
# %matplotlib inline

import numpy as np
import torch
import matplotlib.pyplot as plt

# %%
from torchvision import datasets
import torchvision.transforms as transforms

# number of subprocesses to use for data loading
num_workers = 0
# how many samples per batch to load
batch_size = 64

# convert data to torch.FloatTensor
transform = transforms.ToTensor()

# get the training datasets
train_data = datasets.MNIST(root='data', train=True,
                                   download=True, transform=transform)

# prepare data loader
train_loader = torch.utils.data.DataLoader(train_data, batch_size=batch_size,
                                           num_workers=num_workers)
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Processing...
# Done!

# %% [markdown]
# ### Visualize the data

# %%
# obtain one batch of training images
dataiter = iter(train_loader)
images, labels = dataiter.next()
images = images.numpy()

# get one image from the batch
img = np.squeeze(images[0])

fig = plt.figure(figsize = (3,3)) 
ax = fig.add_subplot(111)
ax.imshow(img, cmap='gray')

# %% [markdown]
# ---
# # Define the Model
#
# A GAN is comprised of two adversarial networks, a discriminator and a generator.

# %% [markdown]
# ## Discriminator
#
# The discriminator network is going to be a pretty typical linear classifier. To make this network a universal function approximator, we'll need at least one hidden layer, and these hidden layers should have one key attribute:
# > All hidden layers will have a [Leaky ReLu](https://pytorch.org/docs/stable/nn.html#torch.nn.LeakyReLU) activation function applied to their outputs.
#
# <img src='assets/gan_network.png' width=70% />
#
# #### Leaky ReLu
#
# We should use a leaky ReLU to allow gradients to flow backwards through the layer unimpeded. A leaky ReLU is like a normal ReLU, except that there is a small non-zero output for negative input values.
#
# <img src='assets/leaky_relu.png' width=40% />
#
# #### Sigmoid Output
#
# We'll also take the approach of using a more numerically stable loss function on the outputs. Recall that we want the discriminator to output a value 0-1 indicating whether an image is _real or fake_.
# > We will ultimately use [BCEWithLogitsLoss](https://pytorch.org/docs/stable/nn.html#bcewithlogitsloss), which combines a `sigmoid` activation function **and** and binary cross entropy loss in one function.
#
# So, our final output layer should not have any activation function applied to it.

# %%
import torch.nn as nn
import torch.nn.functional as F

class Discriminator(nn.Module):

    def __init__(self, input_size, hidden_dim, output_size):
        super(Discriminator, self).__init__()
        
        # define all layers
        self.fc1 = nn.Linear(input_size, hidden_dim*4)
        self.fc2 = nn.Linear(hidden_dim*4, hidden_dim*2)
        self.fc3 = nn.Linear(hidden_dim*2, hidden_dim)
        self.fc4 = nn.Linear(hidden_dim, output_size)
        
        self.dropout = nn.Dropout(0.3)
        
        
    def forward(self, x):
        # flatten image
        x = x.view(-1, 28*28)
        
        # pass x through all layers
        # apply leaky relu activation to all hidden layers
        
        x = F.leaky_relu(self.fc1(x), 0.2) # (input, negative_slope)
        x = self.dropout(x)
        
        x = F.leaky_relu(self.fc2(x), 0.2)
        x = self.dropout(x)
        
        x = F.leaky_relu(self.fc3(x), 0.2)
        x = self.dropout(x)
        
        out = self.fc4(x) # No activation is used here because later BCElogitsloss is used which has inbuilt sigmoid activation

        return out

# %% [markdown]
# ## Generator
#
# The generator network will be almost exactly the same as the discriminator network, except that we're applying a [tanh activation function](https://pytorch.org/docs/stable/nn.html#tanh) to our output layer.
#
# #### tanh Output
# The generator has been found to perform the best with $tanh$ for the generator output, which scales the output to be between -1 and 1, instead of 0 and 1.
#
# <img src='assets/tanh_fn.png' width=40% />
#
# Recall that we also want these outputs to be comparable to the *real* input pixel values, which are read in as normalized values between 0 and 1.
# > So, we'll also have to **scale our real input images to have pixel values between -1 and 1** when we train the discriminator.
#
# I'll do this in the training loop, later on.

# %%
class Generator(nn.Module):

    def __init__(self, input_size, hidden_dim, output_size):
        super(Generator, self).__init__()
        
        # define all layers
        self.fc1 = nn.Linear(input_size, hidden_dim)
        self.fc2 = nn.Linear(hidden_dim, hidden_dim*2)
        self.fc3 = nn.Linear(hidden_dim*2, hidden_dim*4)
        self.fc4 = nn.Linear(hidden_dim*4, output_size)
        
        self.dropout = nn.Dropout(0.3)
        

    def forward(self, x):
        # pass x through all layers
        x = F.leaky_relu(self.fc1(x), 0.2)
        x = self.dropout(x)
        
        x = F.leaky_relu(self.fc2(x), 0.2)
        x = self.dropout(x)
        
        x = F.leaky_relu(self.fc3(x), 0.2)
        x = self.dropout(x)
        
        # final layer should have tanh applied
        out = F.tanh(self.fc4(x))
        
        return out

# %% [markdown]
# ## Model hyperparameters

# %%
# Discriminator hyperparams

# Size of input image to discriminator (28*28)
input_size = 784
# Size of discriminator output (real or fake)
d_output_size = 1
# Size of *last* hidden layer in the discriminator
d_hidden_size = 32

# Generator hyperparams

# Size of latent vector to give to generator
z_size = 100
# Size of generator output (generated image)
g_output_size = 784
# Size of *first* hidden layer in the generator
g_hidden_size = 32

# %% [markdown]
# ## Build complete network
#
# Now we're instantiating the discriminator and generator from the classes defined above. Make sure you've passed in the correct input arguments.

# %%
# instantiate discriminator and generator
D = Discriminator(input_size, d_hidden_size, d_output_size)
G = Generator(z_size, g_hidden_size, g_output_size)

# check that they are as you expect
print(D)
print()
print(G)
# Out:
# Discriminator(
#   (fc1): Linear(in_features=784, out_features=128, bias=True)
#   (fc2): Linear(in_features=128, out_features=64, bias=True)
#   (fc3): Linear(in_features=64, out_features=32, bias=True)
#   (fc4): Linear(in_features=32, out_features=1, bias=True)
#   (dropout): Dropout(p=0.3)
# )
#
# Generator(
#   (fc1): Linear(in_features=100, out_features=32, bias=True)
#   (fc2): Linear(in_features=32, out_features=64, bias=True)
#   (fc3): Linear(in_features=64, out_features=128, bias=True)
#   (fc4): Linear(in_features=128, out_features=784, bias=True)
#   (dropout): Dropout(p=0.3)
# )

# %% [markdown]
# ---
# ## Discriminator and Generator Losses
#
# Now we need to calculate the losses.
#
# ### Discriminator Losses
#
# > * For the discriminator, the total loss is the sum of the losses for real and fake images, `d_loss = d_real_loss + d_fake_loss`.
# * Remember that we want the discriminator to output 1 for real images and 0 for fake images, so we need to set up the losses to reflect that.
#
# <img src='assets/gan_pipeline.png' width=70% />
#
# The losses will by binary cross entropy loss with logits, which we can get with [BCEWithLogitsLoss](https://pytorch.org/docs/stable/nn.html#bcewithlogitsloss). This combines a `sigmoid` activation function **and** and binary cross entropy loss in one function.
#
# For the real images, we want `D(real_images) = 1`. That is, we want the discriminator to classify the the real images with a label = 1, indicating that these are real. To help the discriminator generalize better, the labels are **reduced a bit from 1.0 to 0.9**. For this, we'll use the parameter `smooth`; if True, then we should smooth our labels. In PyTorch, this looks like `labels = torch.ones(size) * 0.9`
#
# The discriminator loss for the fake data is similar. We want `D(fake_images) = 0`, where the fake images are the _generator output_, `fake_images = G(z)`.
#
# ### Generator Loss
#
# The generator loss will look similar only with flipped labels. The generator's goal is to get `D(fake_images) = 1`. In this case, the labels are **flipped** to represent that the generator is trying to fool the discriminator into thinking that the images it generates (fakes) are real!

# %%
# Calculate losses
def real_loss(D_out, smooth=False):
    batch_size = D_out.size(0)
    # compare logits to real labels
    # smooth labels if smooth=True
    if smooth:
        labels = torch.ones(batch_size) * 0.9   # reallabels= 0.9
    else:
        labels = torch.ones(batch_size)        # reallabels = 1
        
    criterion = nn.BCEWithLogitsLoss()
    loss = criterion(D_out.squeeze(), labels)
    return loss

def fake_loss(D_out):
    batch_size = D_out.size(0)                  # fakelabels = 0
    # compare logits to fake labels
    labels = torch.zeros(batch_size)
    criterion = nn.BCEWithLogitsLoss()
    loss = criterion(D_out.squeeze(), labels)
    return loss

# %% [markdown]
# ## Optimizers
#
# We want to update the generator and discriminator variables separately. So, we'll define two separate Adam optimizers.

# %%
import torch.optim as optim

# learning rate for optimizers
lr = 0.002

# Create optimizers for the discriminator and generator
d_optimizer = optim.Adam(D.parameters(), lr)
g_optimizer = optim.Adam(G.parameters(), lr)

# %% [markdown]
# ---
# ## Training
#
# Training will involve alternating between training the discriminator and the generator. We'll use our functions `real_loss` and `fake_loss` to help us calculate the discriminator losses in all of the following cases.
#
# ### Discriminator training
# 1. Compute the discriminator loss on real, training images
# 2. Generate fake images
# 3. Compute the discriminator loss on fake, generated images
# 4. Add up real and fake loss
# 5. Perform backpropagation + an optimization step to update the discriminator's weights
#
# ### Generator training
# 1. Generate fake images
# 2. Compute the discriminator loss on fake images, using **flipped** labels!
# 3. Perform backpropagation + an optimization step to update the generator's weights
#
# #### Saving Samples
#
# As we train, we'll also print out some loss statistics and save some generated "fake" samples.

# %%
import pickle as pkl

# training hyperparams
num_epochs = 200

# keep track of loss and generated, "fake" samples
samples = []
losses = []

print_every = 400

# Get some fixed data for sampling. These are images that are held
# constant throughout training, and allow us to inspect the model's performance
sample_size=16
fixed_z = np.random.uniform(-1, 1, size=(sample_size, z_size))
fixed_z = torch.from_numpy(fixed_z).float()

# train the network
D.train()
G.train()
for epoch in range(num_epochs):
    
    for batch_i, (real_images, _) in enumerate(train_loader):
                
        batch_size = real_images.size(0)
        
        ## Important rescaling step ## 
        real_images = real_images*2 - 1  # rescale input images from [0,1) to [-1, 1]
                                         # Because the generator uses tanh activation which has range -1 to 1.
                                         # We want generator output and real images to be similar.
        
        # ============================================
        #            TRAIN THE DISCRIMINATOR
        # ============================================
        
        d_optimizer.zero_grad()
                
        # 1. Train with real images

        # Compute the discriminator losses on real images
        # use smoothed labels
        
        d_out_real = D(real_images)
        d_loss_real = real_loss(d_out_real, smooth=True)
        
        # 2. Train with fake images
        
        # Generate fake images
        z = np.random.uniform(-1, 1, size=(batch_size, z_size))
        z = torch.from_numpy(z).float()
        fake_images = G(z)
        
        # Compute the discriminator losses on fake images        
        
        d_out_fake = D(fake_images)
        d_loss_fake = fake_loss(d_out_fake)
        
        # add up real and fake losses and perform backprop
        d_loss = d_loss_real + d_loss_fake
        d_loss.backward()
        d_optimizer.step()
        
        
        # =========================================
        #            TRAIN THE GENERATOR
        # =========================================
        
        g_optimizer.zero_grad()
        
        # 1. Train with fake images and flipped labels
        
        # Generate fake images
        z = np.random.uniform(-1, 1, size=(batch_size,z_size))
        z = torch.from_numpy(z).float()
        fake_images = G(z)
        
        # Compute the discriminator losses on fake images 
        # using flipped labels!
        D_fake = D(fake_images)
        g_loss = real_loss(D_fake)  # wanting the fae images to be tuned like real
        
        # perform backprop
        g_loss.backward()
        g_optimizer.step()
        

        # Print some loss stats
        if batch_i % print_every == 0:
            # print discriminator and generator loss
            print('Epoch [{:5d}/{:5d}] | d_loss: {:6.4f} | g_loss: {:6.4f}'.format(
                    epoch+1, num_epochs, d_loss.item(), g_loss.item()))

    
    ## AFTER EACH EPOCH##
    # append discriminator loss and generator loss
    losses.append((d_loss.item(), g_loss.item()))
    
    # generate and save sample, fake images
    G.eval() # eval mode for generating samples
    samples_z = G(fixed_z)
    samples.append(samples_z)
    G.train() # back to train mode


# Save training generator samples
with open('train_samples.pkl', 'wb') as f:
    pkl.dump(samples, f)
# Out:
# Epoch [    1/  200] | d_loss: 1.1665 | g_loss: 1.6378
# Epoch [    1/  200] | d_loss: 1.4186 | g_loss: 0.7572
# Epoch [    1/  200] | d_loss: 1.0171 | g_loss: 1.5536
# Epoch [    2/  200] | d_loss: 1.3306 | g_loss: 1.0068
# Epoch [    2/  200] | d_loss: 1.3400 | g_loss: 0.8599
# Epoch [    2/  200] | d_loss: 1.1485 | g_loss: 1.0636
# Epoch [    3/  200] | d_loss: 1.2111 | g_loss: 1.0993
# Epoch [    3/  200] | d_loss: 1.1081 | g_loss: 2.8537
# Epoch [    3/  200] | d_loss: 0.9108 | g_loss: 2.3251
# Epoch [    4/  200] | d_loss: 0.9149 | g_loss: 2.8191
# Epoch [    4/  200] | d_loss: 0.8423 | g_loss: 1.7423
# Epoch [    4/  200] | d_loss: 1.4549 | g_loss: 1.3406
# Epoch [    5/  200] | d_loss: 1.1833 | g_loss: 1.1805
# Epoch [    5/  200] | d_loss: 0.9747 | g_loss: 3.1434
# Epoch [    5/  200] | d_loss: 0.9240 | g_loss: 3.9426
# Epoch [    6/  200] | d_loss: 1.1211 | g_loss: 4.0265
# Epoch [    6/  200] | d_loss: 0.9610 | g_loss: 1.2538
# Epoch [    6/  200] | d_loss: 0.9128 | g_loss: 2.9862
# Epoch [    7/  200] | d_loss: 1.0084 | g_loss: 2.5651
# Epoch [    7/  200] | d_loss: 1.0149 | g_loss: 1.4199
# Epoch [    7/  200] | d_loss: 1.1191 | g_loss: 2.3931
# Epoch [    8/  200] | d_loss: 1.0814 | g_loss: 1.8035
# Epoch [    8/  200] | d_loss: 1.0557 | g_loss: 1.1300
# Epoch [    8/  200] | d_loss: 1.3351 | g_loss: 0.9936
# Epoch [    9/  200] | d_loss: 1.2406 | g_loss: 0.9230
# Epoch [    9/  200] | d_loss: 1.0213 | g_loss: 1.5047
# Epoch [    9/  200] | d_loss: 1.0549 | g_loss: 1.2970
# Epoch [   10/  200] | d_loss: 1.2439 | g_loss: 1.1308
# Epoch [   10/  200] | d_loss: 1.3077 | g_loss: 1.2347
# Epoch [   10/  200] | d_loss: 1.2688 | g_loss: 1.0822
# Epoch [   11/  200] | d_loss: 1.2786 | g_loss: 0.8918
# Epoch [   11/  200] | d_loss: 1.2087 | g_loss: 0.9879
# Epoch [   11/  200] | d_loss: 1.3720 | g_loss: 1.3663
# Epoch [   12/  200] | d_loss: 1.2906 | g_loss: 1.0119
# Epoch [   12/  200] | d_loss: 1.2439 | g_loss: 0.9150
# Epoch [   12/  200] | d_loss: 1.2232 | g_loss: 1.4145
# Epoch [   13/  200] | d_loss: 1.2873 | g_loss: 1.0067
# Epoch [   13/  200] | d_loss: 1.2451 | g_loss: 1.1244
# Epoch [   13/  200] | d_loss: 1.2723 | g_loss: 0.8228
# Epoch [   14/  200] | d_loss: 1.2605 | g_loss: 0.9926
# Epoch [   14/  200] | d_loss: 1.2827 | g_loss: 1.2076
# Epoch [   14/  200] | d_loss: 1.2808 | g_loss: 0.8582
# Epoch [   15/  200] | d_loss: 1.3278 | g_loss: 0.8896
# Epoch [   15/  200] | d_loss: 1.3683 | g_loss: 0.9591
# Epoch [   15/  200] | d_loss: 1.3161 | g_loss: 0.8765
# Epoch [   16/  200] | d_loss: 1.3875 | g_loss: 0.7877
# Epoch [   16/  200] | d_loss: 1.3049 | g_loss: 0.8783
# Epoch [   16/  200] | d_loss: 1.3647 | g_loss: 0.8932
# Epoch [   17/  200] | d_loss: 1.2510 | g_loss: 1.1953
# Epoch [   17/  200] | d_loss: 1.2992 | g_loss: 0.9620
# Epoch [   17/  200] | d_loss: 1.3659 | g_loss: 0.9398
# Epoch [   18/  200] | d_loss: 1.3079 | g_loss: 1.1624
# Epoch [   18/  200] | d_loss: 1.2041 | g_loss: 1.4559
# Epoch [   18/  200] | d_loss: 1.4296 | g_loss: 1.0331
# Epoch [   19/  200] | d_loss: 1.2251 | g_loss: 0.9729
# Epoch [   19/  200] | d_loss: 1.3575 | g_loss: 0.8115
# Epoch [   19/  200] | d_loss: 1.3016 | g_loss: 1.0883
# Epoch [   20/  200] | d_loss: 1.3046 | g_loss: 1.0998
# Epoch [   20/  200] | d_loss: 1.1877 | g_loss: 1.3191
# Epoch [   20/  200] | d_loss: 1.3338 | g_loss: 0.9501
# Epoch [   21/  200] | d_loss: 1.2277 | g_loss: 0.9514
# Epoch [   21/  200] | d_loss: 1.3823 | g_loss: 0.9979
# Epoch [   21/  200] | d_loss: 1.3842 | g_loss: 0.8518
# Epoch [   22/  200] | d_loss: 1.3082 | g_loss: 0.9095
# Epoch [   22/  200] | d_loss: 1.1834 | g_loss: 0.9324
# Epoch [   22/  200] | d_loss: 1.3558 | g_loss: 0.8595
# Epoch [   23/  200] | d_loss: 1.2569 | g_loss: 1.0147
# Epoch [   23/  200] | d_loss: 1.2781 | g_loss: 0.8940
# Epoch [   23/  200] | d_loss: 1.3784 | g_loss: 1.0861
# Epoch [   24/  200] | d_loss: 1.3087 | g_loss: 1.1081
# Epoch [   24/  200] | d_loss: 1.2473 | g_loss: 0.9582
# Epoch [   24/  200] | d_loss: 1.3126 | g_loss: 0.8973
# Epoch [   25/  200] | d_loss: 1.3165 | g_loss: 0.9833
# Epoch [   25/  200] | d_loss: 1.2961 | g_loss: 0.9190
# Epoch [   25/  200] | d_loss: 1.3237 | g_loss: 1.1651
# Epoch [   26/  200] | d_loss: 1.2485 | g_loss: 1.0211
# Epoch [   26/  200] | d_loss: 1.2945 | g_loss: 0.8713
# Epoch [   26/  200] | d_loss: 1.2925 | g_loss: 0.9464
# Epoch [   27/  200] | d_loss: 1.3651 | g_loss: 1.0767
# Epoch [   27/  200] | d_loss: 1.4408 | g_loss: 0.9350
# Epoch [   27/  200] | d_loss: 1.4141 | g_loss: 0.9914
# Epoch [   28/  200] | d_loss: 1.2049 | g_loss: 1.1230
# Epoch [   28/  200] | d_loss: 1.2749 | g_loss: 1.0355
# Epoch [   28/  200] | d_loss: 1.2178 | g_loss: 1.3774
# Epoch [   29/  200] | d_loss: 1.2572 | g_loss: 1.3185
# Epoch [   29/  200] | d_loss: 1.2472 | g_loss: 0.8964
# Epoch [   29/  200] | d_loss: 1.2489 | g_loss: 1.0882
# Epoch [   30/  200] | d_loss: 1.2588 | g_loss: 0.8871
# Epoch [   30/  200] | d_loss: 1.2387 | g_loss: 0.9474
# Epoch [   30/  200] | d_loss: 1.4236 | g_loss: 1.0419
# Epoch [   31/  200] | d_loss: 1.5220 | g_loss: 1.5139
# Epoch [   31/  200] | d_loss: 1.2101 | g_loss: 1.2926
# Epoch [   31/  200] | d_loss: 1.3613 | g_loss: 1.0054
# Epoch [   32/  200] | d_loss: 1.3079 | g_loss: 0.8339
# Epoch [   32/  200] | d_loss: 1.2150 | g_loss: 1.2120
# Epoch [   32/  200] | d_loss: 1.3256 | g_loss: 1.1129
# Epoch [   33/  200] | d_loss: 1.2887 | g_loss: 1.1109
# Epoch [   33/  200] | d_loss: 1.2822 | g_loss: 1.2751
# Epoch [   33/  200] | d_loss: 1.4537 | g_loss: 0.9595
# Epoch [   34/  200] | d_loss: 1.2910 | g_loss: 1.0592
# Epoch [   34/  200] | d_loss: 1.2675 | g_loss: 1.1313
# Epoch [   34/  200] | d_loss: 1.3216 | g_loss: 1.1414
# Epoch [   35/  200] | d_loss: 1.3102 | g_loss: 0.9988
# Epoch [   35/  200] | d_loss: 1.3233 | g_loss: 1.0611
# Epoch [   35/  200] | d_loss: 1.2665 | g_loss: 0.8859
# Epoch [   36/  200] | d_loss: 1.2961 | g_loss: 0.8917
# Epoch [   36/  200] | d_loss: 1.3231 | g_loss: 0.9900
# Epoch [   36/  200] | d_loss: 1.2859 | g_loss: 0.9583
# Epoch [   37/  200] | d_loss: 1.2271 | g_loss: 1.2909
# Epoch [   37/  200] | d_loss: 1.3490 | g_loss: 0.9041
# Epoch [   37/  200] | d_loss: 1.3337 | g_loss: 1.0003
# Epoch [   38/  200] | d_loss: 1.3261 | g_loss: 0.9379
# Epoch [   38/  200] | d_loss: 1.1949 | g_loss: 0.9927
# Epoch [   38/  200] | d_loss: 1.3858 | g_loss: 1.0170
# Epoch [   39/  200] | d_loss: 1.3587 | g_loss: 0.9030
# Epoch [   39/  200] | d_loss: 1.3234 | g_loss: 0.9886
# Epoch [   39/  200] | d_loss: 1.2761 | g_loss: 0.9830
# Epoch [   40/  200] | d_loss: 1.3175 | g_loss: 0.8294
# Epoch [   40/  200] | d_loss: 1.2745 | g_loss: 1.0684
# Epoch [   40/  200] | d_loss: 1.3428 | g_loss: 1.1869
# Epoch [   41/  200] | d_loss: 1.2952 | g_loss: 1.0080
# Epoch [   41/  200] | d_loss: 1.2974 | g_loss: 0.8852
# Epoch [   41/  200] | d_loss: 1.4204 | g_loss: 0.9980
# Epoch [   42/  200] | d_loss: 1.2951 | g_loss: 0.9812
# Epoch [   42/  200] | d_loss: 1.2906 | g_loss: 1.0147
# Epoch [   42/  200] | d_loss: 1.3117 | g_loss: 1.1693
# Epoch [   43/  200] | d_loss: 1.2946 | g_loss: 0.9914
# Epoch [   43/  200] | d_loss: 1.2561 | g_loss: 0.8897
# Epoch [   43/  200] | d_loss: 1.3595 | g_loss: 1.0341
# Epoch [   44/  200] | d_loss: 1.2346 | g_loss: 1.0626
# Epoch [   44/  200] | d_loss: 1.3402 | g_loss: 0.9986
# Epoch [   44/  200] | d_loss: 1.3959 | g_loss: 0.8904
# Epoch [   45/  200] | d_loss: 1.3703 | g_loss: 0.8124
# Epoch [   45/  200] | d_loss: 1.2251 | g_loss: 1.4352
# Epoch [   45/  200] | d_loss: 1.3588 | g_loss: 1.0091
# Epoch [   46/  200] | d_loss: 1.3352 | g_loss: 0.9079
# Epoch [   46/  200] | d_loss: 1.2506 | g_loss: 0.8455
# Epoch [   46/  200] | d_loss: 1.2535 | g_loss: 0.9896
# Epoch [   47/  200] | d_loss: 1.3688 | g_loss: 1.1572
# Epoch [   47/  200] | d_loss: 1.2865 | g_loss: 0.9746
# Epoch [   47/  200] | d_loss: 1.3727 | g_loss: 0.9359
# Epoch [   48/  200] | d_loss: 1.3417 | g_loss: 0.9270
# Epoch [   48/  200] | d_loss: 1.3217 | g_loss: 0.9372
# Epoch [   48/  200] | d_loss: 1.4555 | g_loss: 1.2066
# Epoch [   49/  200] | d_loss: 1.2792 | g_loss: 0.9171
# Epoch [   49/  200] | d_loss: 1.2980 | g_loss: 0.8690
# Epoch [   49/  200] | d_loss: 1.2568 | g_loss: 1.0121
# Epoch [   50/  200] | d_loss: 1.3315 | g_loss: 0.8769
# Epoch [   50/  200] | d_loss: 1.3106 | g_loss: 1.1436
# Epoch [   50/  200] | d_loss: 1.3939 | g_loss: 0.9483
# Epoch [   51/  200] | d_loss: 1.3436 | g_loss: 0.8050
# Epoch [   51/  200] | d_loss: 1.3403 | g_loss: 0.9537
# Epoch [   51/  200] | d_loss: 1.4285 | g_loss: 0.9208
# Epoch [   52/  200] | d_loss: 1.2285 | g_loss: 1.0163
# Epoch [   52/  200] | d_loss: 1.1911 | g_loss: 1.1968
# Epoch [   52/  200] | d_loss: 1.3401 | g_loss: 0.9379
# Epoch [   53/  200] | d_loss: 1.3139 | g_loss: 0.8366
# Epoch [   53/  200] | d_loss: 1.2525 | g_loss: 0.9882
# Epoch [   53/  200] | d_loss: 1.3194 | g_loss: 1.0459
# Epoch [   54/  200] | d_loss: 1.3665 | g_loss: 0.9487
# Epoch [   54/  200] | d_loss: 1.2573 | g_loss: 1.3737
# Epoch [   54/  200] | d_loss: 1.2913 | g_loss: 0.8158
# Epoch [   55/  200] | d_loss: 1.2957 | g_loss: 0.9752
# Epoch [   55/  200] | d_loss: 1.3073 | g_loss: 0.9981
# Epoch [   55/  200] | d_loss: 1.4433 | g_loss: 0.9387
# Epoch [   56/  200] | d_loss: 1.3495 | g_loss: 0.9656
# Epoch [   56/  200] | d_loss: 1.2663 | g_loss: 1.4597
# Epoch [   56/  200] | d_loss: 1.3334 | g_loss: 0.9095
# Epoch [   57/  200] | d_loss: 1.3322 | g_loss: 0.9779
# Epoch [   57/  200] | d_loss: 1.3452 | g_loss: 1.0973
# Epoch [   57/  200] | d_loss: 1.3421 | g_loss: 0.7836
# Epoch [   58/  200] | d_loss: 1.4412 | g_loss: 0.9037
# Epoch [   58/  200] | d_loss: 1.3135 | g_loss: 0.9860
# Epoch [   58/  200] | d_loss: 1.4079 | g_loss: 1.1644
# Epoch [   59/  200] | d_loss: 1.2772 | g_loss: 0.9653
# Epoch [   59/  200] | d_loss: 1.2884 | g_loss: 1.1610
# Epoch [   59/  200] | d_loss: 1.3947 | g_loss: 1.0127
# Epoch [   60/  200] | d_loss: 1.2383 | g_loss: 0.9082
# Epoch [   60/  200] | d_loss: 1.2234 | g_loss: 1.0764
# Epoch [   60/  200] | d_loss: 1.3732 | g_loss: 0.9229
# Epoch [   61/  200] | d_loss: 1.3400 | g_loss: 1.1579
# Epoch [   61/  200] | d_loss: 1.2645 | g_loss: 1.0553
# Epoch [   61/  200] | d_loss: 1.4079 | g_loss: 1.1660
# Epoch [   62/  200] | d_loss: 1.3794 | g_loss: 0.9781
# Epoch [   62/  200] | d_loss: 1.2242 | g_loss: 1.2522
# Epoch [   62/  200] | d_loss: 1.3387 | g_loss: 0.8900
# Epoch [   63/  200] | d_loss: 1.3494 | g_loss: 1.2914
# Epoch [   63/  200] | d_loss: 1.1609 | g_loss: 1.5294
# Epoch [   63/  200] | d_loss: 1.4281 | g_loss: 0.9681
# Epoch [   64/  200] | d_loss: 1.3818 | g_loss: 0.9772
# Epoch [   64/  200] | d_loss: 1.2755 | g_loss: 0.9462
# Epoch [   64/  200] | d_loss: 1.3339 | g_loss: 1.0603
# Epoch [   65/  200] | d_loss: 1.2853 | g_loss: 1.0046
# Epoch [   65/  200] | d_loss: 1.2946 | g_loss: 0.9561
# Epoch [   65/  200] | d_loss: 1.3422 | g_loss: 0.9923
# Epoch [   66/  200] | d_loss: 1.3730 | g_loss: 1.0249
# Epoch [   66/  200] | d_loss: 1.2428 | g_loss: 1.2018
# Epoch [   66/  200] | d_loss: 1.3108 | g_loss: 0.9899
# Epoch [   67/  200] | d_loss: 1.2692 | g_loss: 1.1899
# Epoch [   67/  200] | d_loss: 1.2903 | g_loss: 1.0755
# Epoch [   67/  200] | d_loss: 1.3987 | g_loss: 0.9695
# Epoch [   68/  200] | d_loss: 1.2952 | g_loss: 0.7910
# Epoch [   68/  200] | d_loss: 1.2683 | g_loss: 0.9255
# Epoch [   68/  200] | d_loss: 1.4123 | g_loss: 0.8692
# Epoch [   69/  200] | d_loss: 1.3408 | g_loss: 1.1548
# Epoch [   69/  200] | d_loss: 1.2881 | g_loss: 0.9756
# Epoch [   69/  200] | d_loss: 1.3358 | g_loss: 0.9372
# Epoch [   70/  200] | d_loss: 1.2105 | g_loss: 1.4090
# Epoch [   70/  200] | d_loss: 1.3245 | g_loss: 1.0239
# Epoch [   70/  200] | d_loss: 1.3887 | g_loss: 0.8546
# Epoch [   71/  200] | d_loss: 1.2359 | g_loss: 1.0263
# Epoch [   71/  200] | d_loss: 1.1716 | g_loss: 1.0082
# Epoch [   71/  200] | d_loss: 1.2879 | g_loss: 1.1225
# Epoch [   72/  200] | d_loss: 1.3246 | g_loss: 0.8682
# Epoch [   72/  200] | d_loss: 1.2832 | g_loss: 1.0101
# Epoch [   72/  200] | d_loss: 1.3962 | g_loss: 0.9074
# Epoch [   73/  200] | d_loss: 1.3622 | g_loss: 1.0651
# Epoch [   73/  200] | d_loss: 1.3258 | g_loss: 0.8316
# Epoch [   73/  200] | d_loss: 1.2872 | g_loss: 1.0785
# Epoch [   74/  200] | d_loss: 1.2880 | g_loss: 0.9887
# Epoch [   74/  200] | d_loss: 1.2327 | g_loss: 1.1118
# Epoch [   74/  200] | d_loss: 1.2878 | g_loss: 1.2901
# Epoch [   75/  200] | d_loss: 1.1988 | g_loss: 1.2781
# Epoch [   75/  200] | d_loss: 1.2433 | g_loss: 1.0547
# Epoch [   75/  200] | d_loss: 1.3669 | g_loss: 1.4758
# Epoch [   76/  200] | d_loss: 1.2734 | g_loss: 1.1714
# Epoch [   76/  200] | d_loss: 1.1537 | g_loss: 1.1905
# Epoch [   76/  200] | d_loss: 1.3119 | g_loss: 0.9891
# Epoch [   77/  200] | d_loss: 1.1295 | g_loss: 1.0189
# Epoch [   77/  200] | d_loss: 1.2529 | g_loss: 0.8778
# Epoch [   77/  200] | d_loss: 1.3151 | g_loss: 0.9536
# Epoch [   78/  200] | d_loss: 1.2160 | g_loss: 1.2039
# Epoch [   78/  200] | d_loss: 1.3359 | g_loss: 1.1277
# Epoch [   78/  200] | d_loss: 1.3160 | g_loss: 0.9287
# Epoch [   79/  200] | d_loss: 1.2336 | g_loss: 0.9217
# Epoch [   79/  200] | d_loss: 1.2455 | g_loss: 1.0317
# Epoch [   79/  200] | d_loss: 1.3241 | g_loss: 0.9733
# Epoch [   80/  200] | d_loss: 1.4239 | g_loss: 1.2080
# Epoch [   80/  200] | d_loss: 1.2684 | g_loss: 1.0002
# Epoch [   80/  200] | d_loss: 1.3133 | g_loss: 0.9558
# Epoch [   81/  200] | d_loss: 1.3546 | g_loss: 1.1174
# Epoch [   81/  200] | d_loss: 1.2477 | g_loss: 1.1303
# Epoch [   81/  200] | d_loss: 1.3794 | g_loss: 0.9896
# Epoch [   82/  200] | d_loss: 1.3189 | g_loss: 0.9969
# Epoch [   82/  200] | d_loss: 1.3094 | g_loss: 0.8231
# Epoch [   82/  200] | d_loss: 1.3431 | g_loss: 1.0751
# Epoch [   83/  200] | d_loss: 1.3375 | g_loss: 1.0431
# Epoch [   83/  200] | d_loss: 1.2627 | g_loss: 0.9554
# Epoch [   83/  200] | d_loss: 1.4696 | g_loss: 1.0218
# Epoch [   84/  200] | d_loss: 1.2088 | g_loss: 1.1449
# Epoch [   84/  200] | d_loss: 1.2328 | g_loss: 1.1492
# Epoch [   84/  200] | d_loss: 1.4589 | g_loss: 0.9653
# Epoch [   85/  200] | d_loss: 1.2348 | g_loss: 0.9508
# Epoch [   85/  200] | d_loss: 1.3170 | g_loss: 0.9530
# Epoch [   85/  200] | d_loss: 1.3228 | g_loss: 0.8209
# Epoch [   86/  200] | d_loss: 1.3158 | g_loss: 0.9872
# Epoch [   86/  200] | d_loss: 1.2862 | g_loss: 0.9986
# Epoch [   86/  200] | d_loss: 1.2926 | g_loss: 1.1060
# Epoch [   87/  200] | d_loss: 1.3167 | g_loss: 1.0104
# Epoch [   87/  200] | d_loss: 1.1694 | g_loss: 0.8852
# Epoch [   87/  200] | d_loss: 1.3043 | g_loss: 1.0210
# Epoch [   88/  200] | d_loss: 1.2723 | g_loss: 1.1032
# Epoch [   88/  200] | d_loss: 1.3038 | g_loss: 0.9782
# Epoch [   88/  200] | d_loss: 1.3469 | g_loss: 1.0903
# Epoch [   89/  200] | d_loss: 1.3699 | g_loss: 1.1601
# Epoch [   89/  200] | d_loss: 1.3780 | g_loss: 0.9286
# Epoch [   89/  200] | d_loss: 1.2984 | g_loss: 1.0498
# Epoch [   90/  200] | d_loss: 1.3435 | g_loss: 1.3292
# Epoch [   90/  200] | d_loss: 1.2875 | g_loss: 1.1605
# Epoch [   90/  200] | d_loss: 1.3157 | g_loss: 0.8845
# Epoch [   91/  200] | d_loss: 1.3777 | g_loss: 0.8513
# Epoch [   91/  200] | d_loss: 1.1384 | g_loss: 1.1493
# Epoch [   91/  200] | d_loss: 1.3354 | g_loss: 0.9769
# Epoch [   92/  200] | d_loss: 1.2485 | g_loss: 1.1511
# Epoch [   92/  200] | d_loss: 1.2484 | g_loss: 1.0954
# Epoch [   92/  200] | d_loss: 1.4558 | g_loss: 1.0714
# Epoch [   93/  200] | d_loss: 1.3273 | g_loss: 1.1146
# Epoch [   93/  200] | d_loss: 1.2695 | g_loss: 1.0679
# Epoch [   93/  200] | d_loss: 1.4466 | g_loss: 1.0401
# Epoch [   94/  200] | d_loss: 1.3408 | g_loss: 0.8832
# Epoch [   94/  200] | d_loss: 1.1919 | g_loss: 0.8431
# Epoch [   94/  200] | d_loss: 1.3445 | g_loss: 0.9762
# Epoch [   95/  200] | d_loss: 1.2283 | g_loss: 1.1816
# Epoch [   95/  200] | d_loss: 1.1647 | g_loss: 1.0498
# Epoch [   95/  200] | d_loss: 1.4101 | g_loss: 1.0502
# Epoch [   96/  200] | d_loss: 1.3512 | g_loss: 1.2027
# Epoch [   96/  200] | d_loss: 1.3650 | g_loss: 1.2154
# Epoch [   96/  200] | d_loss: 1.2291 | g_loss: 1.0738
# Epoch [   97/  200] | d_loss: 1.3019 | g_loss: 0.9637
# Epoch [   97/  200] | d_loss: 1.3109 | g_loss: 1.0908
# Epoch [   97/  200] | d_loss: 1.3371 | g_loss: 1.0015
# Epoch [   98/  200] | d_loss: 1.3775 | g_loss: 0.7217
# Epoch [   98/  200] | d_loss: 1.2582 | g_loss: 0.9135
# Epoch [   98/  200] | d_loss: 1.3887 | g_loss: 0.9354
# Epoch [   99/  200] | d_loss: 1.2664 | g_loss: 1.1180
# Epoch [   99/  200] | d_loss: 1.3011 | g_loss: 1.0474
# Epoch [   99/  200] | d_loss: 1.3128 | g_loss: 0.9349
# Epoch [  100/  200] | d_loss: 1.3098 | g_loss: 0.8921
# Epoch [  100/  200] | d_loss: 1.2038 | g_loss: 1.1120
# Epoch [  100/  200] | d_loss: 1.3064 | g_loss: 1.1262
# Epoch [  101/  200] | d_loss: 1.2621 | g_loss: 1.3450
# Epoch [  101/  200] | d_loss: 1.2926 | g_loss: 1.0403
# Epoch [  101/  200] | d_loss: 1.3888 | g_loss: 0.8805
# Epoch [  102/  200] | d_loss: 1.2472 | g_loss: 0.9238
# Epoch [  102/  200] | d_loss: 1.2546 | g_loss: 1.3796
# Epoch [  102/  200] | d_loss: 1.3996 | g_loss: 1.0829
# Epoch [  103/  200] | d_loss: 1.3306 | g_loss: 1.2223
# Epoch [  103/  200] | d_loss: 1.3217 | g_loss: 1.1141
# Epoch [  103/  200] | d_loss: 1.3963 | g_loss: 1.0199
# Epoch [  104/  200] | d_loss: 1.3276 | g_loss: 0.8790
# Epoch [  104/  200] | d_loss: 1.2628 | g_loss: 0.9417
# Epoch [  104/  200] | d_loss: 1.2637 | g_loss: 0.9310
# Epoch [  105/  200] | d_loss: 1.2236 | g_loss: 1.0851
# Epoch [  105/  200] | d_loss: 1.2639 | g_loss: 0.8572
# Epoch [  105/  200] | d_loss: 1.3460 | g_loss: 1.1529
# Epoch [  106/  200] | d_loss: 1.2940 | g_loss: 1.0848
# Epoch [  106/  200] | d_loss: 1.3033 | g_loss: 0.9803
# Epoch [  106/  200] | d_loss: 1.3896 | g_loss: 1.0034
# Epoch [  107/  200] | d_loss: 1.3194 | g_loss: 1.0042
# Epoch [  107/  200] | d_loss: 1.2159 | g_loss: 1.0405
# Epoch [  107/  200] | d_loss: 1.3149 | g_loss: 0.9150
# Epoch [  108/  200] | d_loss: 1.2108 | g_loss: 0.9674
# Epoch [  108/  200] | d_loss: 1.3583 | g_loss: 0.9750
# Epoch [  108/  200] | d_loss: 1.3170 | g_loss: 1.1588
# Epoch [  109/  200] | d_loss: 1.3122 | g_loss: 1.1399
# Epoch [  109/  200] | d_loss: 1.3074 | g_loss: 1.0123
# Epoch [  109/  200] | d_loss: 1.3429 | g_loss: 1.2443
# Epoch [  110/  200] | d_loss: 1.1580 | g_loss: 1.2626
# Epoch [  110/  200] | d_loss: 1.3374 | g_loss: 1.0453
# Epoch [  110/  200] | d_loss: 1.3943 | g_loss: 1.0787
# Epoch [  111/  200] | d_loss: 1.3198 | g_loss: 1.0365
# Epoch [  111/  200] | d_loss: 1.2428 | g_loss: 1.3049
# Epoch [  111/  200] | d_loss: 1.2914 | g_loss: 1.0095
# Epoch [  112/  200] | d_loss: 1.3122 | g_loss: 0.9984
# Epoch [  112/  200] | d_loss: 1.3600 | g_loss: 0.9617
# Epoch [  112/  200] | d_loss: 1.3467 | g_loss: 0.9855
# Epoch [  113/  200] | d_loss: 1.3538 | g_loss: 1.0039
# Epoch [  113/  200] | d_loss: 1.2087 | g_loss: 0.9133
# Epoch [  113/  200] | d_loss: 1.3569 | g_loss: 1.0788
# Epoch [  114/  200] | d_loss: 1.2674 | g_loss: 1.0045
# Epoch [  114/  200] | d_loss: 1.3167 | g_loss: 1.0914
# Epoch [  114/  200] | d_loss: 1.2512 | g_loss: 1.1172
# Epoch [  115/  200] | d_loss: 1.3110 | g_loss: 1.1856
# Epoch [  115/  200] | d_loss: 1.2266 | g_loss: 1.0917
# Epoch [  115/  200] | d_loss: 1.3504 | g_loss: 1.0943
# Epoch [  116/  200] | d_loss: 1.3052 | g_loss: 1.1492
# Epoch [  116/  200] | d_loss: 1.2026 | g_loss: 0.8906
# Epoch [  116/  200] | d_loss: 1.1910 | g_loss: 1.0104
# Epoch [  117/  200] | d_loss: 1.2679 | g_loss: 1.1546
# Epoch [  117/  200] | d_loss: 1.2467 | g_loss: 0.9320
# Epoch [  117/  200] | d_loss: 1.3727 | g_loss: 0.9396
# Epoch [  118/  200] | d_loss: 1.3088 | g_loss: 1.3230
# Epoch [  118/  200] | d_loss: 1.2366 | g_loss: 1.1810
# Epoch [  118/  200] | d_loss: 1.3211 | g_loss: 1.0018
# Epoch [  119/  200] | d_loss: 1.2890 | g_loss: 1.0704
# Epoch [  119/  200] | d_loss: 1.2513 | g_loss: 0.9886
# Epoch [  119/  200] | d_loss: 1.4119 | g_loss: 1.1516
# Epoch [  120/  200] | d_loss: 1.2148 | g_loss: 0.9635
# Epoch [  120/  200] | d_loss: 1.2270 | g_loss: 0.9158
# Epoch [  120/  200] | d_loss: 1.3005 | g_loss: 1.0127
# Epoch [  121/  200] | d_loss: 1.2721 | g_loss: 1.2247
# Epoch [  121/  200] | d_loss: 1.2970 | g_loss: 0.8569
# Epoch [  121/  200] | d_loss: 1.2252 | g_loss: 1.4414
# Epoch [  122/  200] | d_loss: 1.2186 | g_loss: 0.8569
# Epoch [  122/  200] | d_loss: 1.2143 | g_loss: 1.0172
# Epoch [  122/  200] | d_loss: 1.4253 | g_loss: 0.9142
# Epoch [  123/  200] | d_loss: 1.2516 | g_loss: 0.9921
# Epoch [  123/  200] | d_loss: 1.2669 | g_loss: 1.0533
# Epoch [  123/  200] | d_loss: 1.3821 | g_loss: 0.9509
# Epoch [  124/  200] | d_loss: 1.3160 | g_loss: 1.1809
# Epoch [  124/  200] | d_loss: 1.1999 | g_loss: 0.9189
# Epoch [  124/  200] | d_loss: 1.2807 | g_loss: 1.0869
# Epoch [  125/  200] | d_loss: 1.2608 | g_loss: 1.1518
# Epoch [  125/  200] | d_loss: 1.1680 | g_loss: 1.0320
# Epoch [  125/  200] | d_loss: 1.4331 | g_loss: 1.0848
# Epoch [  126/  200] | d_loss: 1.2634 | g_loss: 1.3034
# Epoch [  126/  200] | d_loss: 1.0821 | g_loss: 1.2231
# Epoch [  126/  200] | d_loss: 1.4251 | g_loss: 1.1569
# Epoch [  127/  200] | d_loss: 1.3062 | g_loss: 0.7998
# Epoch [  127/  200] | d_loss: 1.1497 | g_loss: 0.9478
# Epoch [  127/  200] | d_loss: 1.3317 | g_loss: 1.0320
# Epoch [  128/  200] | d_loss: 1.2663 | g_loss: 1.4161
# Epoch [  128/  200] | d_loss: 1.2589 | g_loss: 0.9694
# Epoch [  128/  200] | d_loss: 1.3222 | g_loss: 1.0127
# Epoch [  129/  200] | d_loss: 1.2096 | g_loss: 1.1012
# Epoch [  129/  200] | d_loss: 1.2436 | g_loss: 1.3027
# Epoch [  129/  200] | d_loss: 1.3155 | g_loss: 1.1685
# Epoch [  130/  200] | d_loss: 1.3373 | g_loss: 1.0327
# Epoch [  130/  200] | d_loss: 1.1936 | g_loss: 1.1737
# Epoch [  130/  200] | d_loss: 1.2868 | g_loss: 1.1841
# Epoch [  131/  200] | d_loss: 1.2321 | g_loss: 1.2759
# Epoch [  131/  200] | d_loss: 1.2527 | g_loss: 1.1416
# Epoch [  131/  200] | d_loss: 1.2956 | g_loss: 1.0845
# Epoch [  132/  200] | d_loss: 1.2628 | g_loss: 1.4493
# Epoch [  132/  200] | d_loss: 1.2206 | g_loss: 1.1785
# Epoch [  132/  200] | d_loss: 1.2927 | g_loss: 1.2446
# Epoch [  133/  200] | d_loss: 1.3133 | g_loss: 0.9536
# Epoch [  133/  200] | d_loss: 1.1771 | g_loss: 1.0184
# Epoch [  133/  200] | d_loss: 1.2982 | g_loss: 1.1853
# Epoch [  134/  200] | d_loss: 1.4216 | g_loss: 1.4517
# Epoch [  134/  200] | d_loss: 1.2419 | g_loss: 1.1228
# Epoch [  134/  200] | d_loss: 1.4133 | g_loss: 1.2930
# Epoch [  135/  200] | d_loss: 1.3007 | g_loss: 0.7705
# Epoch [  135/  200] | d_loss: 1.2867 | g_loss: 1.0695
# Epoch [  135/  200] | d_loss: 1.2822 | g_loss: 1.0105
# Epoch [  136/  200] | d_loss: 1.3517 | g_loss: 1.1108
# Epoch [  136/  200] | d_loss: 1.2611 | g_loss: 1.0234
# Epoch [  136/  200] | d_loss: 1.3264 | g_loss: 1.1209
# Epoch [  137/  200] | d_loss: 1.2695 | g_loss: 0.9932
# Epoch [  137/  200] | d_loss: 1.3537 | g_loss: 0.9467
# Epoch [  137/  200] | d_loss: 1.3657 | g_loss: 0.9696
# Epoch [  138/  200] | d_loss: 1.3291 | g_loss: 1.3811
# Epoch [  138/  200] | d_loss: 1.2054 | g_loss: 1.3908
# Epoch [  138/  200] | d_loss: 1.3941 | g_loss: 1.0240
# Epoch [  139/  200] | d_loss: 1.2263 | g_loss: 1.1796
# Epoch [  139/  200] | d_loss: 1.3706 | g_loss: 0.9795
# Epoch [  139/  200] | d_loss: 1.3600 | g_loss: 1.1558
# Epoch [  140/  200] | d_loss: 1.2882 | g_loss: 0.9247
# Epoch [  140/  200] | d_loss: 1.2017 | g_loss: 1.0721
# Epoch [  140/  200] | d_loss: 1.3486 | g_loss: 1.0470
# Epoch [  141/  200] | d_loss: 1.2053 | g_loss: 0.9606
# Epoch [  141/  200] | d_loss: 1.2673 | g_loss: 1.0075
# Epoch [  141/  200] | d_loss: 1.4291 | g_loss: 1.0077
# Epoch [  142/  200] | d_loss: 1.2691 | g_loss: 1.1017
# Epoch [  142/  200] | d_loss: 1.3030 | g_loss: 1.0312
# Epoch [  142/  200] | d_loss: 1.3594 | g_loss: 1.0110
# Epoch [  143/  200] | d_loss: 1.2036 | g_loss: 1.1153
# Epoch [  143/  200] | d_loss: 1.2404 | g_loss: 0.9798
# Epoch [  143/  200] | d_loss: 1.3381 | g_loss: 1.2841
# Epoch [  144/  200] | d_loss: 1.4311 | g_loss: 0.8982
# Epoch [  144/  200] | d_loss: 1.3076 | g_loss: 0.9981
# Epoch [  144/  200] | d_loss: 1.3155 | g_loss: 0.9248
# Epoch [  145/  200] | d_loss: 1.3005 | g_loss: 1.2151
# Epoch [  145/  200] | d_loss: 1.2270 | g_loss: 0.9894
# Epoch [  145/  200] | d_loss: 1.2893 | g_loss: 0.9317
# Epoch [  146/  200] | d_loss: 1.3411 | g_loss: 1.2808
# Epoch [  146/  200] | d_loss: 1.2846 | g_loss: 0.8907
# Epoch [  146/  200] | d_loss: 1.2489 | g_loss: 0.9642
# Epoch [  147/  200] | d_loss: 1.2910 | g_loss: 0.9848
# Epoch [  147/  200] | d_loss: 1.2833 | g_loss: 1.1940
# Epoch [  147/  200] | d_loss: 1.2362 | g_loss: 1.0717
# Epoch [  148/  200] | d_loss: 1.3191 | g_loss: 0.8778
# Epoch [  148/  200] | d_loss: 1.3241 | g_loss: 0.9811
# Epoch [  148/  200] | d_loss: 1.4713 | g_loss: 1.3604
# Epoch [  149/  200] | d_loss: 1.3123 | g_loss: 1.0089
# Epoch [  149/  200] | d_loss: 1.1738 | g_loss: 0.9234
# Epoch [  149/  200] | d_loss: 1.3410 | g_loss: 1.2180
# Epoch [  150/  200] | d_loss: 1.2960 | g_loss: 1.0439
# Epoch [  150/  200] | d_loss: 1.2716 | g_loss: 1.0049
# Epoch [  150/  200] | d_loss: 1.3917 | g_loss: 1.1446
# Epoch [  151/  200] | d_loss: 1.1936 | g_loss: 1.0617
# Epoch [  151/  200] | d_loss: 1.3756 | g_loss: 0.9854
# Epoch [  151/  200] | d_loss: 1.3665 | g_loss: 1.0837
# Epoch [  152/  200] | d_loss: 1.2900 | g_loss: 0.9846
# Epoch [  152/  200] | d_loss: 1.3458 | g_loss: 0.9467
# Epoch [  152/  200] | d_loss: 1.2236 | g_loss: 0.9076
# Epoch [  153/  200] | d_loss: 1.2768 | g_loss: 1.1914
# Epoch [  153/  200] | d_loss: 1.2768 | g_loss: 1.1475
# Epoch [  153/  200] | d_loss: 1.2272 | g_loss: 1.0239
# Epoch [  154/  200] | d_loss: 1.1932 | g_loss: 1.4486
# Epoch [  154/  200] | d_loss: 1.2225 | g_loss: 1.1084
# Epoch [  154/  200] | d_loss: 1.3748 | g_loss: 0.9706
# Epoch [  155/  200] | d_loss: 1.4261 | g_loss: 1.2395
# Epoch [  155/  200] | d_loss: 1.3392 | g_loss: 1.0310
# Epoch [  155/  200] | d_loss: 1.1922 | g_loss: 1.2677
# Epoch [  156/  200] | d_loss: 1.2537 | g_loss: 1.0856
# Epoch [  156/  200] | d_loss: 1.1679 | g_loss: 1.1047
# Epoch [  156/  200] | d_loss: 1.2749 | g_loss: 0.9471
# Epoch [  157/  200] | d_loss: 1.1708 | g_loss: 1.3317
# Epoch [  157/  200] | d_loss: 1.2168 | g_loss: 1.0554
# Epoch [  157/  200] | d_loss: 1.1954 | g_loss: 1.0681
# Epoch [  158/  200] | d_loss: 1.2465 | g_loss: 1.0680
# Epoch [  158/  200] | d_loss: 1.2628 | g_loss: 1.2562
# Epoch [  158/  200] | d_loss: 1.3291 | g_loss: 0.9545
# Epoch [  159/  200] | d_loss: 1.2355 | g_loss: 1.3013
# Epoch [  159/  200] | d_loss: 1.2890 | g_loss: 1.3009
# Epoch [  159/  200] | d_loss: 1.2950 | g_loss: 1.1520
# Epoch [  160/  200] | d_loss: 1.2220 | g_loss: 1.1121
# Epoch [  160/  200] | d_loss: 1.1785 | g_loss: 1.0329
# Epoch [  160/  200] | d_loss: 1.3577 | g_loss: 0.9492
# Epoch [  161/  200] | d_loss: 1.1973 | g_loss: 1.1549
# Epoch [  161/  200] | d_loss: 1.2237 | g_loss: 1.0584
# Epoch [  161/  200] | d_loss: 1.2889 | g_loss: 1.1725
# Epoch [  162/  200] | d_loss: 1.2603 | g_loss: 1.0037
# Epoch [  162/  200] | d_loss: 1.1969 | g_loss: 1.2432
# Epoch [  162/  200] | d_loss: 1.2820 | g_loss: 1.0697
# Epoch [  163/  200] | d_loss: 1.4160 | g_loss: 1.0468
# Epoch [  163/  200] | d_loss: 1.2770 | g_loss: 1.4274
# Epoch [  163/  200] | d_loss: 1.3193 | g_loss: 1.0094
# Epoch [  164/  200] | d_loss: 1.2878 | g_loss: 1.0067
# Epoch [  164/  200] | d_loss: 1.1433 | g_loss: 0.9000
# Epoch [  164/  200] | d_loss: 1.2976 | g_loss: 1.0607
# Epoch [  165/  200] | d_loss: 1.1757 | g_loss: 1.3588
# Epoch [  165/  200] | d_loss: 1.2667 | g_loss: 1.5212
# Epoch [  165/  200] | d_loss: 1.3026 | g_loss: 1.1494
# Epoch [  166/  200] | d_loss: 1.3306 | g_loss: 0.9367
# Epoch [  166/  200] | d_loss: 1.3281 | g_loss: 1.1025
# Epoch [  166/  200] | d_loss: 1.3012 | g_loss: 1.0362
# Epoch [  167/  200] | d_loss: 1.2528 | g_loss: 0.9679
# Epoch [  167/  200] | d_loss: 1.1340 | g_loss: 1.2925
# Epoch [  167/  200] | d_loss: 1.3439 | g_loss: 1.0400
# Epoch [  168/  200] | d_loss: 1.3426 | g_loss: 1.1601
# Epoch [  168/  200] | d_loss: 1.2353 | g_loss: 1.2504
# Epoch [  168/  200] | d_loss: 1.3754 | g_loss: 1.1620
# Epoch [  169/  200] | d_loss: 1.4281 | g_loss: 0.9763
# Epoch [  169/  200] | d_loss: 1.2148 | g_loss: 1.2353
# Epoch [  169/  200] | d_loss: 1.2703 | g_loss: 0.8972
# Epoch [  170/  200] | d_loss: 1.3191 | g_loss: 1.1236
# Epoch [  170/  200] | d_loss: 1.2143 | g_loss: 0.9860
# Epoch [  170/  200] | d_loss: 1.1841 | g_loss: 1.3870
# Epoch [  171/  200] | d_loss: 1.1945 | g_loss: 1.0874
# Epoch [  171/  200] | d_loss: 1.1466 | g_loss: 1.1998
# Epoch [  171/  200] | d_loss: 1.2945 | g_loss: 1.0228
# Epoch [  172/  200] | d_loss: 1.2274 | g_loss: 1.0705
# Epoch [  172/  200] | d_loss: 1.2188 | g_loss: 1.1801
# Epoch [  172/  200] | d_loss: 1.3150 | g_loss: 1.1053
# Epoch [  173/  200] | d_loss: 1.2145 | g_loss: 1.0489
# Epoch [  173/  200] | d_loss: 1.2343 | g_loss: 1.1107
# Epoch [  173/  200] | d_loss: 1.2453 | g_loss: 1.0945
# Epoch [  174/  200] | d_loss: 1.1388 | g_loss: 1.5736
# Epoch [  174/  200] | d_loss: 1.2238 | g_loss: 1.1033
# Epoch [  174/  200] | d_loss: 1.3506 | g_loss: 0.9298
# Epoch [  175/  200] | d_loss: 1.3297 | g_loss: 0.9602
# Epoch [  175/  200] | d_loss: 1.2917 | g_loss: 1.2196
# Epoch [  175/  200] | d_loss: 1.3119 | g_loss: 0.9323
# Epoch [  176/  200] | d_loss: 1.2627 | g_loss: 1.1129
# Epoch [  176/  200] | d_loss: 1.2643 | g_loss: 1.4439
# Epoch [  176/  200] | d_loss: 1.2242 | g_loss: 1.0269
# Epoch [  177/  200] | d_loss: 1.3301 | g_loss: 1.8543
# Epoch [  177/  200] | d_loss: 1.0871 | g_loss: 1.0675
# Epoch [  177/  200] | d_loss: 1.3286 | g_loss: 1.1806
# Epoch [  178/  200] | d_loss: 1.3005 | g_loss: 1.3576
# Epoch [  178/  200] | d_loss: 1.0894 | g_loss: 0.9793
# Epoch [  178/  200] | d_loss: 1.3047 | g_loss: 1.0332
# Epoch [  179/  200] | d_loss: 1.2965 | g_loss: 1.2717
# Epoch [  179/  200] | d_loss: 1.1586 | g_loss: 1.3282
# Epoch [  179/  200] | d_loss: 1.2106 | g_loss: 1.1573
# Epoch [  180/  200] | d_loss: 1.2977 | g_loss: 1.3495
# Epoch [  180/  200] | d_loss: 1.1683 | g_loss: 1.0500
# Epoch [  180/  200] | d_loss: 1.4898 | g_loss: 1.2492
# Epoch [  181/  200] | d_loss: 1.1807 | g_loss: 1.6802
# Epoch [  181/  200] | d_loss: 1.1769 | g_loss: 1.3155
# Epoch [  181/  200] | d_loss: 1.2648 | g_loss: 0.9283
# Epoch [  182/  200] | d_loss: 1.3011 | g_loss: 1.1405
# Epoch [  182/  200] | d_loss: 1.1396 | g_loss: 1.1706
# Epoch [  182/  200] | d_loss: 1.4174 | g_loss: 1.1259
# Epoch [  183/  200] | d_loss: 1.1512 | g_loss: 1.2073
# Epoch [  183/  200] | d_loss: 1.1538 | g_loss: 1.0970
# Epoch [  183/  200] | d_loss: 1.4093 | g_loss: 0.8714
# Epoch [  184/  200] | d_loss: 1.3402 | g_loss: 1.1358
# Epoch [  184/  200] | d_loss: 1.1795 | g_loss: 0.9993
# Epoch [  184/  200] | d_loss: 1.3393 | g_loss: 0.9179
# Epoch [  185/  200] | d_loss: 1.2882 | g_loss: 1.0716
# Epoch [  185/  200] | d_loss: 1.2354 | g_loss: 1.0576
# Epoch [  185/  200] | d_loss: 1.2549 | g_loss: 1.2623
# Epoch [  186/  200] | d_loss: 1.2441 | g_loss: 1.3296
# Epoch [  186/  200] | d_loss: 1.2064 | g_loss: 0.8264
# Epoch [  186/  200] | d_loss: 1.3107 | g_loss: 1.0506
# Epoch [  187/  200] | d_loss: 1.1957 | g_loss: 1.3695
# Epoch [  187/  200] | d_loss: 1.3820 | g_loss: 1.2402
# Epoch [  187/  200] | d_loss: 1.2701 | g_loss: 1.4688
# Epoch [  188/  200] | d_loss: 1.4539 | g_loss: 1.1625
# Epoch [  188/  200] | d_loss: 1.2502 | g_loss: 1.3849
# Epoch [  188/  200] | d_loss: 1.2993 | g_loss: 1.1635
# Epoch [  189/  200] | d_loss: 1.2930 | g_loss: 1.1435
# Epoch [  189/  200] | d_loss: 1.2098 | g_loss: 1.0262
# Epoch [  189/  200] | d_loss: 1.2313 | g_loss: 1.1622
# Epoch [  190/  200] | d_loss: 1.2401 | g_loss: 1.3140
# Epoch [  190/  200] | d_loss: 1.1284 | g_loss: 1.1327
# Epoch [  190/  200] | d_loss: 1.3187 | g_loss: 0.9644
# Epoch [  191/  200] | d_loss: 1.1884 | g_loss: 1.1420
# Epoch [  191/  200] | d_loss: 1.1716 | g_loss: 0.9892
# Epoch [  191/  200] | d_loss: 1.2710 | g_loss: 1.0330
# Epoch [  192/  200] | d_loss: 1.3176 | g_loss: 1.0644
# Epoch [  192/  200] | d_loss: 1.1995 | g_loss: 1.0036
# Epoch [  192/  200] | d_loss: 1.3030 | g_loss: 0.9643
# Epoch [  193/  200] | d_loss: 1.2496 | g_loss: 1.2285
# Epoch [  193/  200] | d_loss: 1.1299 | g_loss: 0.9400
# Epoch [  193/  200] | d_loss: 1.2903 | g_loss: 1.2299
# Epoch [  194/  200] | d_loss: 1.2448 | g_loss: 1.2544
# Epoch [  194/  200] | d_loss: 1.2303 | g_loss: 1.0233
# Epoch [  194/  200] | d_loss: 1.1789 | g_loss: 1.1235
# Epoch [  195/  200] | d_loss: 1.1187 | g_loss: 0.9849
# Epoch [  195/  200] | d_loss: 1.2693 | g_loss: 1.1224
# Epoch [  195/  200] | d_loss: 1.2854 | g_loss: 1.0953
# Epoch [  196/  200] | d_loss: 1.3290 | g_loss: 1.5097
# Epoch [  196/  200] | d_loss: 1.2660 | g_loss: 1.1684
# Epoch [  196/  200] | d_loss: 1.3490 | g_loss: 0.9891
# Epoch [  197/  200] | d_loss: 1.1446 | g_loss: 0.8013
# Epoch [  197/  200] | d_loss: 1.1946 | g_loss: 1.1067
# Epoch [  197/  200] | d_loss: 1.2558 | g_loss: 1.1832
# Epoch [  198/  200] | d_loss: 1.2399 | g_loss: 1.1132
# Epoch [  198/  200] | d_loss: 1.2561 | g_loss: 1.2524
# Epoch [  198/  200] | d_loss: 1.3025 | g_loss: 1.3793
# Epoch [  199/  200] | d_loss: 1.3189 | g_loss: 1.2113
# Epoch [  199/  200] | d_loss: 1.2971 | g_loss: 1.2736
# Epoch [  199/  200] | d_loss: 1.2780 | g_loss: 0.9786
# Epoch [  200/  200] | d_loss: 1.1951 | g_loss: 1.2555
# Epoch [  200/  200] | d_loss: 1.2183 | g_loss: 1.1506
# Epoch [  200/  200] | d_loss: 1.2246 | g_loss: 1.4516

# %% [markdown]
# ## Training loss
#
# Here we'll plot the training losses for the generator and discriminator, recorded after each epoch.

# %%
fig, ax = plt.subplots()
losses = np.array(losses)
plt.plot(losses.T[0], label='Discriminator')
plt.plot(losses.T[1], label='Generator')
plt.title("Training Losses")
plt.legend()

# %% [markdown]
# ## Generator samples from training
#
# Here we can view samples of images from the generator. First we'll look at the images we saved during training.

# %%
# helper function for viewing a list of passed in sample images
def view_samples(epoch, samples):
    fig, axes = plt.subplots(figsize=(7,7), nrows=4, ncols=4, sharey=True, sharex=True)
    for ax, img in zip(axes.flatten(), samples[epoch]):
        img = img.detach()
        ax.xaxis.set_visible(False)
        ax.yaxis.set_visible(False)
        im = ax.imshow(img.reshape((28,28)), cmap='Greys_r')

# %%
# Load samples from generator, taken while training
with open('train_samples.pkl', 'rb') as f:
    samples = pkl.load(f)

# %% [markdown]
# These are samples from the final training epoch. You can see the generator is able to reproduce numbers like 1, 7, 3, 2. Since this is just a sample, it isn't representative of the full range of images this generator can make.

# %%
# -1 indicates final epoch's samples (the last in the list)
view_samples(-1, samples)

# %% [markdown]
# Below I'm showing the generated images as the network was training, every 10 epochs.

# %%
rows = 10 # split epochs into 10, so 100/10 every 10 epochs
cols = 6
fig, axes = plt.subplots(figsize=(7,12), nrows=rows, ncols=cols, sharex=True, sharey=True)

for sample, ax_row in zip(samples[::int(len(samples)/rows)], axes):
    for img, ax in zip(sample[::int(len(sample)/cols)], ax_row):
        img = img.detach()
        ax.imshow(img.reshape((28,28)), cmap='Greys_r')
        ax.xaxis.set_visible(False)
        ax.yaxis.set_visible(False)

# %% [markdown]
# It starts out as all noise. Then it learns to make only the center white and the rest black. You can start to see some number like structures appear out of the noise like 1s and 9s.

# %% [markdown]
# ## Sampling from the generator
#
# We can also get completely new images from the generator by using the checkpoint we saved after training. **We just need to pass in a new latent vector $z$ and we'll get new samples**!

# %%
# randomly generated, new latent vectors
sample_size=16
rand_z = np.random.uniform(-1, 1, size=(sample_size, z_size))
rand_z = torch.from_numpy(rand_z).float()

G.eval() # eval mode
# generated samples
rand_images = G(rand_z)

# 0 indicates the first set of samples in the passed in list
# and we only have one batch of samples, here
view_samples(0, [rand_images])
